# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/unpackAI/BL101/blob/main/course_notebooks/Week_4_GameFi%26SocialFi/04_GameFi_SocialFi_Coursebook.ipynb)

# %% [markdown]
# # 💻Welcome to Week 4 of the BC101 Bootcamp
#
# You have successfully finished the second week! At this point you have already learnt so much about the state of the Blockchain industry. This week we will take you ahead of the curve and introduce you to a new and upcoming field: *GameFi & SocialFi*.
#
# ## 📕 Learning Objectives
#
# * Learn what makes GameFi potentially the next stage to enable mainestream blockchain adoption.
# * Get an overview of the current GameFi & SocialFi landscape
# * Understand the differents between on-chain and off-chain gaming
# * Become familiar with some key players inside the GameFi & SocialFi industry
#
# ## 📅 Weekly Progress
#
# |Week | Content | Learning Objectives|
# |:--- |:--- | :--- |
# | 1 | Hello Blockchain World | Get to know more about your classmates, the mentors, and learn about the fundamental concepts of the Blockchain, how it works, and write your first smart contract.|
# | 2 | Non-fungible Tokens (NFTs)| Learn more about Non-fungible Tokens (NFTs) and go through the protocols that make them unique and valuable. Create your own NFT collection, deploy it to a Testnet and view it on OpenSea. |
# | 3 | Decentralised Finance (DeFi)| Understand the major innovation behind DeFi, learn about the most popular DeFi protocols, and create your own cryptocurrency and DeFi project for others to interact with. |
# | **4** | **GameFi & SocialFi** | **Discover a new field in Blockchain that has experienced explosive growth and tapped into concepts such as play-to-earn that currently push the boundaries of blockchain technology application beyond finance. Integrate your own SocialFi project with your DeFi and NFT project.** |
# | 5 | Decentralised Autonomous Orgaizations (DAOs) & Personal Project  | Find out why DAOs are the industries standard as the governing entity for blockchain-based organizations and how they handle voting mechanisms and tokenomics to make the entire organization function. Go through the process of building your own DAO, and pitch your own Blockchain project to the class. Successfully graduate from the Bootcamp and receive your Blockchain certification. |

# %% [markdown]
# ## Introduction into GameFi/SocialFi
# This week we will be diving into the newly developing field of blockchain application: GameFi/SocialFi. Let's start with defining the two fields.
#
# > **GameFi (GameFinance)** involves blockchain games that offer economic incentives to play them, otherwise known as play-to-earn games. Typically, players can earn in-game rewards by completing tasks, battling other players or progressing through various game levels. Additionally, the player is able to own game assets in form of NFTs that can evolve and develop throughout the game.
#
# > **SocialFi (SocialFinance)** is a combination of social networking and finance to create decentralized social applications. Typically, network participants interact through social challenges, through which they can earn in-game rewards.
#
# Arguably, this field will offer a new cycle of Blockchain innovation beyond DeFi, and possibly initiate mass adoption to attract an entirely new wave of users.
#
# However, while GameFi/SocialFi shows promise, recent examples have branded this industry to be more of a ponzi scheme rather than a new and exciting developing field. As such, we will critically address the issues the industry have faced while also outlining the potential for growth.
#
# It is important to note that GameFi and SocialFi are categories on their own and should be differentiated. Currently however, a lot of projects are intertwined in either category which makes it difficult to fully seperate them. We expect that the differences will become more clear and distinct as the fields develop. *Let's dive in ...*

# %% [markdown]
# ### GameFi/SocialFi through the lense of data.
#
# The global video gaming market offers the opportunity to acquire 3bn active video game players, and address an industry with a market size of $235bn per year (in 2022).
#
# To compare this with the current market capitalization in GameFi/SocialFi we are closing in on around [$10bn](https://coinmarketcap.com/view/gaming/?page=1) with an active player base of around [800k](https://dappradar.com/topic/games).
#
# <center><img src="https://www.dropbox.com/s/nni53rvcujmumx0/GameFi%20Users.png?raw=1"/></center>
#
# As we previously mostly explored the Ethereum Blockchain, which dominated the DeFi era, we are now seeing more and more chains that support promising GameFi projects, and provide the infrastructure with a focus on GameFi. Since GameFi projects generally require a higher scale of transactions due to in-game trades and rewards, a low transaction fee (i.e. gas fee) is critical. This is where Ethereum struggles due to its consensus mechanism and other aspects. At current Ethereum still supports the most amount of GameFi projects, however, the Binance Smart Chain (BSC) is a close second. While Ethereum puts a lot of emphasis on decentralisation and stability, BSC focusses on quicker and cheaper on-chain transactions. Such differences are based on the trade-offs chains have to take. Commonly known also as the [Blockchain Trilemma](https://medium.com/certik/the-blockchain-trilemma-decentralized-scalable-and-secure-e9d8c41a87b3), a term coined by Vitalik Buterin.
#
# <center><img src="https://www.dropbox.com/s/lg4cucq4d9845da/GameFi%20Projects.png?raw=1"/></center>
#
# While Ethereum leads in the amount of GameFi projects supported, the Wax Blockchain leads in the amount of active players with a staggering 43%. A high percentage of that is contributed by a popular GameFi game called [Alien Worlds](https://alienworlds.io/), of which [many are bots](https://thedefiant.io/rogue-bots-are-draining-millions-of-dollars-from-wax-blockchains-star-dapp-alien-worlds/) that have been programmed to play-and-earn to make profits. It is also important to note, that the most promising projects have not come out yet. Most are in beta stage and have not yet officially been launched. Some we will dive into later.
#
# <center><img src="https://www.dropbox.com/s/pqx03nsy23rtdo1/Players%20by%20Chain.png?raw=1"/></center>
#
# Lastly, we would also like to highlight the fundraising environment in GameFi. Many VCs recognise the potential and have invested millions.
#
# <center><img src="https://www.dropbox.com/s/qsrunddh5o3kcnd/Fundraising%20stats.png?raw=1"/></center>
#
# All of the above shows the massive opportunity on a macro scale. But how can this potential be realised? What is holding Crypto Gaming back? For that, we will have to dive into the Token Economy of Crypto Games, and how their business model works.
#
# > As always, you can further explore the data above [here](https://www.footprint.network/@Bond/GameFi-Overview).

# %% [markdown]
# ### The Token Economy of GameFi projects.
#
# #### The basic principles of a Game economy
#
# A game’s economy is the flow of resources between its systems and players. You move through the game, complete tasks and win challenges through which you are rewarded with the in-game currency which can be used to buy items. Sounds familiar? Well thats because in-game economies have existed for a long-time. What is new to crypto games however, are the core concepts of decentralisation and autonomy. As a player you are not simply investing your time for the entertainment, but also have the chance to own part of the game yourself by owning game native tokens or in-game NFT items. Either can be exchanged for real money at any point, which makes a functioning token economy critical for a games success.
#
# When talking game economies there are two helpful concepts: Taps and sinks.
#
# A tap is the source of in-game resources (i.e. you receive gold for finishing quests). A sink is where resources are destroyed or exchanged (i.e. buy an item for the gold earned). The analogy of a tap and a sink makes a lot of sense because it allows us to build a mental picture of a resources flow; If the tap is generating the resource quicker than the sink can remove it then an excess builds. Any resource that is in excess becomes effectively worthless to the player and they stop interacting with the tap.
#
# However, the inverse can also be true: When there is too little resource coming from a tap then there is little motivation for a player to interactive with it. The correct balance between a tap and a sink is known as a pinch point.
#
# In economics a pinch point is the level of supply of a commodity at which demand is maximised due to consumers becoming concerned about the supply. In games we can think about this as the point where the supply shows the utility of a resource but is scarce enough to have players continue to seek it.
#
# <img src="https://www.dropbox.com/s/qhn35ctoxqur9jy/Tap-and-Sink-In-Balance.jpeg?raw=1" alt="etherscan_week1" width="300"/>

# %% [markdown]
# #### Play-to-earn
#
# The way crypto games have tried to achieve a pinch point, while still attracting crypto native players, is through the play-to-earn model. In order to enter and play-to-earn, players have to make an initial investment to qualify. This normally comes in form of an NFT, that costs around $100 to $1k (prices can vary due to volatility of coin prices) and differs based on their in-game traits and utility. Some might be more expensive due to a more variable trait such as being able to generate more resources more quickly. Now you can start earning.
#
# Such model works if the player base continues to rise and earned currency is reinvested into the economy, instead of simply being earned-and-dumped (exchanged for ETH or another currency outside the game's reach). If however, there are no new incoming players to purchase NFTs to play-to-earn and the existing playerbase is not reinvesting into the economy, the result will be an inflationary game economy.

# %% [markdown]
# #### Inflation & Deflation
#
# Just like in the real economy, **inflation** and the abundance of in-game resources lead to an increase in cost of items. Additionally, the value of the token falls. For a player base that at current mostly consists of crypto investors who are driven by earning first, and put no emphasis on if the game is "fun", such outcome would be deadly.
#
# If the game provides enough incentive to reinvest and burn the players tokens in the process, the supply of overall coins is reduced and can increase prices and therefore benefits the remaining holders. As such, token holders often like token burnt when there is a set supply cap, making the token **deflationary**.

# %% [markdown]
# #### Multi-token economy
#
# A game economy usually contain more than one in-game token that has one of the following functions (if you are able to discover new exciting projects with other token functionalities, let us know). These functions could be represented by:
#
# - **Governance Tokens**: These tokens act much like company shares, with the holder able to use their tokens to vote on gameplay and to gain a share of a profit.
# - **Utility Tokens**: A token which can be exchanged for some kind of utility, such as crafting items, increasing speed of production, etc.
# - **Non-Fungible Tokens (NFTs)**: A token with unique metadata that is one of a kind. This token may also grant governance or utility aspects too, such as the ability to earn and or partake in competitions.
#
# Without further redo, lets explore existing game economies.

# %% [markdown]
# ### Example Cases
#
# #### Axie Infinity
#
# One of the most prominent GameFi games is called [Axie Infinity](https://axieinfinity.com/). It was arguably the first game that proved the viability of the play-to-earn model. At some point, they had 2,800,000 daily active players, that traded USD 3.6bn in their in-game marketplace, with one of their NFTs to be sold for USD 820,000.
#
# The game is a virtual world full of pets called Axies. Axies can be battled, collected, and used to earn cryptocurrencies. Players need to connect with a special wallet specially developed for Axies designed for running on *Ronin*, an Ethereum sidechain. Players further need to download the game.
#
# ![Example of Axies Infinitiy](https://www.dropbox.com/s/6u3haleu4z8ishh/axies.gif?raw=1)
#
# Axie's game economy centers around three tokens. The in-game cryptocurrency SLP; the axie NFTS; and the "governance token" AXS. The game produces two of those resources in constantly increasing quantities. SLP is earned through player-versus-player battles, and, previously it was also available by completing daily quests and grinding in single-player mode, the equivalent of printing money and handing it to players in large quantities. Axies can be bred several times to produce new creatures and are largely immortal, so the breeding mechanic increases the pool of NFTs.
#
# <img src="https://www.dropbox.com/s/pf0vkgy630gtzsk/axie_gameeconomy.png?raw=1" alt="etherscan_week1" width="600"/>
#
# We previously discussed that games often include economic "sinks" that burn resources without producing more. By contrast, Axie Infinity players had two main options: they could sell their SLP — which pumped it back into the ecosystem — or use it to breed axies whose main function is producing even more SLP. Either way, they were creating more resources and watering down the value of everything acquired in the game. This resulted in a disastrous development of their in-game currency.
#
# <img src="https://www.dropbox.com/s/f7zsbwtvuwienxs/slpcoin.png?raw=1" alt="etherscan_week1" width="600"/>
#
# Being the first-mover, other projects have learned from their success and failure. One of these projects is called Genopets.

# %% [markdown]
# #### Genopets
#
# [Genopets](https://www.genopets.me/) prides themselves to be the first move-to-earn NFT game with the goal to motivate individuals to live an active lifestyle. The are currently in closed beta, but have build an engaged community and proposed a game economy that learns from the mistakes of other GameFi projects. From a gameplay perspective you can imagine their game to play like Pokemon Go.
#
# Players convert real-life movement into XP to progress in the game. Players own so called Genopets that travels around with you and can fight against other players. Additionally, habitats can be purchased that unlock additional functionalities.
#
# <img src="https://www.dropbox.com/s/ktlhslcmga7hm7u/Genopets_image.png?raw=1" alt="etherscan_week1" width="600"/>
#
#
# Similarly like in Axie, the game economy centers around a government token `$GENE` (that can be staked to earn income), an in-game reward token `$KI`, `XP` (not a currency but a reward that increases the power of your Genopet through walking by changing its metadata), and in-game NFTs that can come in form of a Genopet, Crystal (affects gameplay and evolves Genopet), and habitats. This results in a highly progressive game economy.
#
# Players can join the game as a free-to-play player (improving their freely acquired Genopet), or as a play-to-earn player (by purchasing a habitat NFT) to earn $KI, craft crystals or habitats or evolve their Genopet.
#
# <img src="https://www.dropbox.com/s/q245rjfg9bmbj38/genopets_economy.png?raw=1" alt="etherscan_week1" width="600"/>
#
# Their game is expected to be launched towards the end of 2022, which is when we will be able to observe how their game economy will perform. With this let's discuss on how blockchain games are actually implemented.

# %% [markdown]
# #### On-chain Gaming
# Blockchain games are games that have some of their core mechanics handled by the blockchain. It’s a continuum ranging from **"weakly" on-chain games** that for example only require the player to buy an NFT to play the off-chain game, to **"strongly" on-chain games** that require the player to interact with the blockchain in every detail of the game.
#
# Running a game completely on-chain is difficult to be economically profitable. That is why most of the blockchain games that have been released in the past few years are in a hybrid form, having only a few components of their stack on-chain while running the core part of their game logics on off-chain proprietary servers.
#
# ##### "Weakly" on-chain
# For weakly on-chain games the game logic is off-chain. Interoperability is very stricted and only possible between game assets. These game assets are often NFTs representing e.g. a character or a weapon:
#
# <img src="https://www.dropbox.com/s/zfrziy27ht0af4w/weakly_on-chain.png?raw=1" width="500"/>
#
# *The advantages of weakly on-chain games still outnumbers the disadvantages:*
#
# **Advantages and Disadvantages of weakly on-chain gaming**
#
# |Pros |Cons|
# |:---|:--|
# | easy to scale | top-down game development |
# | accessible to the public audience|closed source code *(usually)*|
# | good user experience (UX)|gamers need to trust developer|
# | low latency|proprietary *(the game does not belong to the gamers)* |
# | quick bug-fixing| non-persistent *(developer can change core game functionality anytime)*|
# |cheaters can be banned more quickly|weak composability and interoperability|
#
# The biggest downside with weakly on-chain gaming is that the game developer or publisher acts as a central authoritiy and could start censoring, changing rules, increase prices or disappear. Hence, the concept of *play-to-earn* is finally in the hands of the game publisher.
#
# On the good side, the user experience is quite similar to traditional games, and connection time is not a problem. Updates (e.g. to fix bugs) can be done centrally and players who play against the terms of services can be banned quickly.
#
#
# ##### "Strongly" on-chain
# **Strongly on-chain** games store all assets, skills, game and building logic, etc. fully on the blockchain. Every game component is stored in smart contracts and therefore potentially composable, interoperable, and infinitely duplicable. These components can be NTFs representing skill trees or *quest factory contracts* where anyone can deploy and import their game missions.
# Like for all games where the source code is open and the game logic revealed, a certain kind of randomness is necessary. As we briefly discussed in week 2 and 3 (👉🏻 *Oracle Problem*) real randomness is not natively possible on the blockchain and for true randomness only doable with the help of *chainlink vrf*.
#
# <img src="https://www.dropbox.com/s/t4qjrxfmpajd7qi/strongly_on-chain.png?raw=1" width="500"/>
#
# In strongly on-chain games, every state change of the gaming contracts requires to be registered on-chain. Hence, users need to sign a transaction for each action they are willing to execute in-game.
#
# **Advantages and Disadvantages of strongly on-chain gaming**
#
#
# | Pros | Cons|
# |--|--|
# | complete open-source | UX |
# | bottom-up game development | information not hidden by default |
# | composable and interoperable (thru smart contracts) | players can be identified thru "backrunning" |
# | Client abstraction | latency |
# | no or minimal trust needed | bugs-fixing might require social coordination |
# | no permissions | "botting" |
# | persistent| - |
#
# *Back running* denotes the exploitation of players caused by constantly altering the games parameters. *Blotters* create digital record of all game moves to gain advantage by forecasting other gamers behaviour.
#
#
# ##### Challenges in on-chain GameFi and how it might be solved <a name="cite_ref-CHE"></a>[<sup>[CHE]</sup>](#cite_note-CHE)
# >GameFi comes with excitement and skepticism: record-breaking fund-raising, play-to-earn business model, more control for players in the upcoming metaverse, etc. on the one side. And still unsolved issues related to on-chain gaming on the other side.
#
# *In the following section we list down some issues which are still not fully solved and offer perspectives on how they might be solved in the future.*
#
#
# |Challenge|Overview|Solution|
# |--|--|--|
# |**multi-accounting**|mitigate sybil attacks ruining the gaming experience|1. NFT-based access, 2. proof-of-humanity, 3. reputation system |
# |**key management**|balancing UX and security requirements|1. local & temporary keys, 2. smart wallets & multisignature|
# |**hiding information**|obscuring private gameplay information on a public database|1. commit-reveal schemes, 2. zero-knowledge proofs|
# |**cheat-to-earn**|hack play-to-earn games to earn more rewards|1. mitigate botting, 2. decentralized anti-cheat, 3. reputation system|
#
# - **Multi-accounting** refers to how to identify the player. *Most games implicitly rely on the following rule: one player = one human. If not, this means that someone else could be playing in the name of the player*. Possible solutions are:
#     - An NFT acts as a proof of ownership. The NFT should also be costly enough so that "hijacking" another players account is not worth it.
#     - To proof a player's human identity can come in many ways: a player can proof her identity by performing specific actions (e.g. minimum number of votes) or the game can have a built-in reputation system for every player (e.g. reputation increases with total time played). Finally, some third-party services (e.g. [Proof of Humanity](https://www.proofofhumanity.id/) offer on-chain identity-checking.
#
# - **Key Management** refers to the use of private keys to sign transactions. *The more actions players can perform, the more they will have to sign transactions, the more the Metamask wallet will pop up and annoy the player.* Possible solutions are:
#     - key pairs for "non-sensitive" game actions stored temporary (e.g. during game session) local or on a client side
#     - use of **smart wallets** in which players can define in advance which kind of transactions are allowed
#
#
# - **Hiding Information** refers to the problem that every player can look up the others players move on the blockchain. *Games like poker would be useless on-chain*. Possible solutions are:
#     - Commit-reveal schemes use hashing to store "game-sensitive" information on-chain. E.g.: for a game like **rock-scissor-paper** each player would hash his choice together with a number or word. After both players transmitted the hash they have to reveal their number to proof the correctness of their choice.
#     - Zero-knowledge proofs store only the result of a set of actions on-chain rather than the actions itself (e.g. a cook does not need to reveal it's recipe to prove that he can cook a certain meal or a sudoku solution can be proofed by summing up rows and columns).
#
#
# - **Cheat-to-earn** refers to the problem that players could use *game-bots* which plays in their behalf. This is not a pure on-chain gaming problem as it is more a problem in play-to-earn settings. Possible solutions are:
#     - make the game settings too difficult for bots
#     - implement human interactions (e.g. players need to interact ocassionally on *Discord*)
#     - reward player with a "clean" cheating history or implement a strict rule that any cheating will result in banning.
#
# >*These are all problems that hasn't been solved as a whole by any blockchain game so far. However, some games already implemented solutions to these challenges and further progress can be expected. In the mean-time *weakly-chained gaming* will characterize most games. Also the block time and overall blockchain speed is a problem until blockchains have sped up.*

# %% [markdown]
# ## GameFi & SocialFi Industry and Landscape
# >The GameFi & SocialFi landscape is quickly evolving. In this chapter we want to give you an (neither systematic nor fully covered) overview of the current situation by introducing some existing projects, infrastructure components and future developments.

# %% [markdown]
# ### Infrastructure
# #### WAX
# [WAX](https://on.wax.io/wax-io/) (Worldwide Asset Exchange) is a decentralized platform that enables users to operate a fully functioning virtual marketplace with zero investment in security, infrastructure, or payment processing. Its protocol serves as a decentralized blockchain solution that focuses on the seamless transfer of virtual goods.
# According to their website _"WAX provides everything a brand needs to launch a successful NFT collection — from games and dApps to exchanges, digital marketplaces and more."_.
#
# WAX has its own tokenization model with monetization capabilities similiar to DeFi projects together with their own wallet.
#
# WAX introduced a special form of NFTs: **vIRL NFT**.
# A vIRL NFT is an NFT on the WAX blockchain (or whatever blockchain might support it) that is linked to a physical item that can be redeemed at any point in time.
#
# Think about the following use case: *you want to buy a new pair of shoes which is dropped at a specific store to a specific time. The shoes in your size are limited in supply and you are afraid to miss it or don't have time to be at the shop right in time. vIRL NFTs solves this and many other problems. If the pair of shoes was tied to a vIRL NFT, you could buy the NFT from your home. Now that you have your NFT, you're free to use it to speculate on the price of the shoes just like you would a regular pair of Yeezys.*
#
# **Technology**
# WAX's protocol is primarily focused on serving games, but it has been configured in such a way that it is able to adapt to the needs of various other retail market segments. WAX makes use of **[DPoS](https://everipedia.org/wiki/lang_en/dpos-delegated-proof-of-stake)** (Delegated-Proof-Of-Stake). DPoS was first implemented by the *Bitshares* blockchain. Other digital currencies like *Crypti* followed. We already learnt about PoS (Proof of Stake). The relationship between PoS and DPoS is often described as this between *direct* and *representative democracies*:
# - in PoS every wallet which contains coins is able to *stake*, i.e. to participate in the process of validating transactions, to form the distributed consensus and to earn coins in return
# - in DPoS every wallet which contains coins is able to vote for delegates: these delegates then validate transactions, maintain the blockchain and take the transaction fees as profit.
#
# Furthermore, WAX claims that their Proof-of-Stake based blockchain is carbon-neutral.
#
# #### StarkNet
# [StarkNet](https://starkware.co/starknet/) is a good example of a  **Zero-knowledge rollup** (ZK-rollup). It operates as an L2 network over Ethereum, enabling any dApp to achieve unlimited scale for its computation – without compromising Ethereum's composability and security.
#
# ZK-rollups are Layer 2 blockchain networks which are derrived or inherited from layer 1 blockchains like Ethereum.
#
# ZK-rollups use a mathematical construct called *Merkle Tree* (or hash tree 👉🏻 week1: *like block hashing but in a tree structure*): a zk-rollup consists of two Merkle Trees which are both stored on-chain. One tree is dedicated to store accounts, while the other stores all balances. Any other type of data generated and used by the zk-rollup is stored off-chain.
#
# One of the reasons why zk-rollups manage to perform significantly better than Layer 1 counterparts is the off-chain storage of data. Merkle Trees only consist of the most important data relevant to the smart contract and are accessed and requested to output information much more infrequently than in Layer 1 solutions. This saves huge amounts of processing power and time for the blockchain.
#
# With a ZK-rollup, validating a block is quicker and cheaper because less data is included. It's also secure and decentralized, since the data that is needed to recover the state is stored on the layer 1 chain (Ethereum).
#
# Zk-rollups are becoming increasingly popular both among developers who are looking to boost usability, and among investors and traders looking for faster and cheaper transaction processing.
#
# #### MatchboxDAO
# [MatchboxDAO](https://golden-racer-395.notion.site/Matchbox-Mission-and-Core-Activities-0612f3903f4d48fbb69de05a20b9489c) is a collective of developers, artists, and designers building the infrastructure of on-chain games with StarkNet.
#
# Their primary objectives are:
# 1.	to sponsor the creation of blockchain games
# 2.	to maintain and build repositories of gaming utilities and components
# 3.	publish content regarding blockchain game concepts, tools, and ideas
# 4.	provide mentorship for aspiring game developers
# 5.	connect developers, artists, writers, and VCs
#
# According to MatchboxDAO the problem about the current state of GameFi development is:
# >*"There is no single community in web3 in which developers and thinkers build on-chain games together. This means information and utilities are siloed, and different developers are building identical tools separately. Developers need a single set of resources from which to build their games.
# >Due to the technical limitations of blockchain, it is hard to create a compelling gaming experience on-chain. Developers need mentorship and community support to translate their visions into engaging and fun games. "Due to the technical limitations of blockchain, it is hard to create a compelling gaming experience on-chain. Developers need mentorship and community support to translate their visions into engaging and fun games."*
#
# As a solution they provide grants and mentorship allowing contributors to create on-chain games without financial concerns or contractual obligations.

# %% [markdown]
# ### "Weakly" On-Chain Projects

# %% [markdown]
# #### Sorare
# [Sorare](https://sorare.com/) is a football fantasy game in which participants use digital player cards to buy, sell, trade and manage a virtual team. It's a typical example for a "weakly" on-chain game as it only requires to buy an NFT to play the off-chain game.
#
#  <img src='https://www.dropbox.com/s/zolhpsu0i2gzrgm/Sorare_website.jpg?raw=1' alt="Screenshot of Sorares website" width=500px>
#
#
# #### Illuvium
#
# [Illuvium](https://www.illuvium.io/) is an open-world exploration, NFT creature collector and autobattler game built on the Ethereum Blockchain, releasing on PC and Mac in 2022. Play-to-earn in a graphically-rich sci-fi adventure and conquer the wilderness to help your crash-landed crew flourish. It's future is highly promising as its well-financed and backed by a team of 150 people. While this is no indication for success their shown gameplay has the quality of a triple A game.
#
# <img src='https://www.dropbox.com/s/istrxd8lg7n5tn2/illuvium-gameplay.png?raw=1' alt="illuvium_gameplay" width=500px>
#
#
# #### The Sandbox
# The [Sandbox project](https://www.sandbox.game/en/) is a famous GameFi project, branding itself as *"a blockchain-based virtual world run on the Ethereum blockchain, integrating gaming with decentralised finance, blockchain technology and the metaverse"*.
#
# Players buy, sell and trade digital assets (NFTs) through their marketplaces such as land, decorations, character customization, gaming experience and more. The Sandbox includes `VoxEdit` - an NFT creator software, `GAMEMAKER`- a toolbox for building games and `Avatar` - a sandbox for creating avatars.
#
# Digital land is at the core of the Sandbox ecosystem with each of the 166,464 total pieces of land taking up 96 square metres of in-game land. Each piece of LAND is its own NFT. Several pieces of land can be combined together into estates and furthermore into districts if owned by several people.
#
# <img src='https://www.dropbox.com/s/2vr1l8h2d2fgl4f/Sandbox_NFT_marketplace.jpg?raw=1' alt="Sandbox NFT marketplace" width=500px>
#
# #### Decentraland
# [Decentraland](https://decentraland.org/) is another big GameFi project. On first sight it reminds of *Second Life* but with the difference that Decentraland is owned by its inhabitants and not by the developing team.
#
# <img src='https://www.dropbox.com/s/0yavdloum90xogj/decentraland.gif?raw=1' alt="Decentraland GIF">
#
# Decentraland is a virtual reality platform powered by the Ethereum blockchain. Users can create, experience, and monetize content and applications. Land in Decentraland is permanently owned by the community, giving them full control over their creations.
# Users claim ownership of virtual land on a blockchain-based ledger of parcels. Landowners control what content is published to their portion of land, which is identified by a set of cartesian coordinates (x,y). Contents can range from static 3D scenes to interactive systems such as games.
#
# #### TIMEPieces
# [TIMEPieces](https://time.com/collection/timepieces-nft/) is an NFT community initiated by the Time Magazin similiar to the *Bored Ape Yacht Club*.
#
# Since March 2021, TIME has developed initiatives in web3 that have led to the development of a community of over 40,000 artists, collectors and enthusiasts. TIMEPieces has dropped five collections: Genesis, Inspiration, Long Neckie Women of the Year, Slices of TIME, Timbaland, and Beatclub Collection.
#
# <img src='https://www.dropbox.com/s/nlv8e1p1e0ilb3m/Timepieces.jpg?raw=1' alt="TIMEPieces example">
#
# It's hard to evaluate wether TIMEPieces count as an SocialFi project - we leave it open to you.
#
# #### Yellow Heart
# [YellowHeart](https://yh.io) is an NFT ticketing and music company aiming to _"disrupt the ticketing industry and transforming how artists and fans connect"_. It's a Music NFT marketplace and also a good example for tokenization: in the center of their protocoll is **The HRTS token** - an utilitiy ERC-20 token which can be used for
# - paying
# - staking
# - rewards
#
# We mention it here as an example for another related category *MusicFi*: a combination of Music and DeFi.

# %% [markdown]
# ### "Strongly" On-Chain Projects
#
# #### Conquest
# [Conquest](https://conquest.eth.link/) is _"an unstoppable and open-ended game of strategy and diplomacy running on the Ethereum Virtual Machine"._ (according to their website)
#
# The gameplay (as described after starting the game) is:
# >To participate you'll have to first acquire planets by depositing a stake in form of (Play tokens).
# >These planets will then produce spaceships that you can use to attack other planets. You'll also have to make sure you have enough spaceships to protect your planets. It is a good idea to reach out to other player and plan strategies together.
# >At any time (whether you acquired the planet via staking or via attack), you can exit the planet. This take 3 days during which you cannot use it but at the end of which you ll get the deposit, ready to be withdrawn.
# >Be careful, even though your planet will continue to produce spaceships, you can lose it while waiting for the exit period to end.
#
# <img src='https://www.dropbox.com/s/fasl3ojnb3c4kw6/conquest-demo.gif?raw=1' width="600" alt="Conquest example">
#
# Conquest has been designed from the beginning to run fully permision-less and open ended. Players can join and leave at any time. Plus of course, as an onchain game, conquest is also interoperable. This basically makes conquest a protocol.
#
# Conquest is running on *Gnosis Chain* (an Ethereum sidechain with 5-second block times and low gas prices).
# It is experimental and there is risk involving with playing *(according to their own warning!)*, but if you like to play anyway, you can try it out [here](https://defcon.conquest.etherplay.io/)
#
#
# #### Cometh
# [Cometh](https://www.cometh.io/) is a next generation blockchain game with fair player centric economics. The game is free to play and play to own. Players engage in galactic battles with strategies based on their deck of cards. The cards are not sold by Cometh but crafted by the players using the resources they hoard from winning battles as well as tokens available in DeFi protocols. Cometh organizes tournaments and championships to bolster the community and to support the eSport activities.
#
# The first version of the game was deployed in February 2021 and runs on Polygon Network.
#
# #### Dope Wars
# [Dope Wars](https://dopewars.gg/) is a fully decentralized, community driven, gaming metaverse project inspired by hip-hop culture.
#
# <img src='https://www.dropbox.com/s/y20d6zhkj90jopi/dopewars.jpeg?raw=1' width="600" alt="Dopewars screenshot">
#
# To start playing the game you need configurable NFT characters called "Hustlers". These NFTs are used to level up game characters and can be traded on secondary markets.
#
# Dope Wars is also an experiment in decentralized project finance and governance using a *DAO*. According to their website, they have no venture capital funding and revenue comes from royalties of NFT sales.
#
# Interesting is also the overall game design: it mirrors a 90s vintage webdesign "look & feel", probably to "cover" the shortcomings of strongly on-chain games play fun.

# %% [markdown]
# #### Other projects
# >A few other *strongly on-chain* projects which we just want to mention here are:
#
# **[briq](https://briq.construction/)**
# *... is an NFT construction protocol based around fundamental elements called briqs. You can assemble your briqs into an NFT and disassemble it to get the briqs back and build something else. briqs are NFT building blocks. briq is currently in alpha on StarkNet testnet.*
#
# **[Loot](https://www.lootproject.com/)**
# *... is an adventure game where players can collect "loot bags": randomized adventurer gear generated and stored on chain. The objective of the game is open to the player: stats, images, and other functionality are intentionally omitted for others to interpret.*
#
# **[The Ninth](https://ninth.gg/)**
# *.. is a metaverse game powered by StarkNet with multi-epoch iterations, trade markets, DAOs, game guilds and virtual buildings.*
#
# **[Influence](https://www.influenceth.io/)**
# *... is an open-economy, space strategy MMO in which players colonize asteroids, build infrastructure, discover technologies and engage in combat.*

# %% [markdown]
# ### Metaverse
# The metaverse is a three-dimensional virtual space that resembles our real world. Users in the Metaverse can come together inside a digital universe, socialize, and do activities like playing games, visiting shopping malls, working in a virtual office and hanging out with friends.
#
# <img src='https://www.dropbox.com/s/xl33sow5qymvt4a/meta_metaverse_example.gif?raw=1' alt="Metaverse example">
#
# Although the term metaverse is a placeholder for a lot of things and hopes, one can mentally replace the term with **cyberspace** as in most of the time, the meaning won't substantially change.
#
# Usually, technology companies - when they talk about *the metaverse* - refer to virtual reality (VR) and augmented reality (AR):
#
# - VR is a computer-generated environment with scenes and objects that appear to be real, making the user feel they are immersed in their surroundings. This environment is perceived through a device like VR headset, goggle, helmet, motion controller and/or data suits.
# - AR combines aspects of the digital and physical worlds.
#
# Other than in more *traditional* VR applications the virtual worlds of the metaverse continue to exist persistently even when you're not playing.
#
# Another important aspect of the metaverse is the concept about a new digital economy, where users can create, buy, and sell goods virtually - hoping to overcome the disadvantages of *web2* where users content is often owned by big tech and monetizing content often limited. Metaverse therefore stands for *web3*: virtually all user content is *tokenizable* and transferable by the user.
#
# **Some more or less curious projects jumping onto the metaverse bandwagon**
# - **Coca-Cola** launched a [Zero Sugar Byte flavor born in the metaverse](https://www.coca-colacompany.com/news/coca-cola-creations-zero-sugar-byte-launch)
# - **Shiba Inu** - the Ethereum-based altcoin [announced that it's launching its version of the metaverse](https://www.fool.com/the-ascent/cryptocurrency/articles/shiba-inu-announces-the-launch-of-its-metaverse/)
# - **Amnesia Ibiza** - a famous dance club on Ibiza - [is building a virtual dance club](https://medium.com/predict/amnesia-ibiza-is-building-a-virtual-dance-club-in-decentraland-656396c2072f) on the Metaverse.

# %% [markdown]
# ## Future Development
# ### SocialFi Development
#
# The center of SocialFi is NFTs. NFTs make it possible to securely trade and sell digital content. They enable digital proof of ownership in real-world experiences that brands can create for their communities. Brands can generate revenues from these experiences after-the-fact, inspiring them to create viral content in the metaverse. E-Commerce will be extended by a virtual dimension in the metaverse leading to a marketing section: **virtual commerce** (V-Commerce):
# V-Commerce refers to a blend of digital and physical commerce. Unlike E-Commerce, V-Commerce will build a more seamless mix of digital and physical realities.
#
# It can be also expected that more and more GameFi and SocialFi projects will merge together on-chain. For example: the *TIME* magazin (alrady owner of [TIME Pieces](https://time.com/collection/timepieces-nft/) - an NFT collection community) just announced a joint venture with *The Sandbox* to work together on the metaverse. On the other side it is also possible that concentration and segmentation processes in the market might lead to a more visable differentiation of SocialFi and GameFi.
#
# At this moment, there are only about 300 million crypto users out of the world population of 7.9 billion people. The growth potential therefore is uncapped.
#
# Identification is still an unsolved issue, although it's not a problem solely to web3. A promising approach is **Proof of Identity**. We will cover this next week (👉🏻 DAO).
#
# ### GameFi Development
# If we count *CryptoKittens* as the first example of how gaming could be introduced onto blockchains in November 2017 - *almost 2 years after Ethereum was introduced* - then we are as of today already 5 years into the GameFi age.
#
# The number of GameFi projects has boomed in 2021 and will likely continue to grow in the coming years. As of March 2022, there are more than 1,400 blockchain games listed in *DappRadar* with popular games across multiple blockchains, such as Ethereum, BNB Smart Chain (BSC), Polygon, Harmony, Solana, and many more.
#
# As blockchain technology continues to develop, the GameFi growing trend is expected to continue at a fast pace. The ability to own in-game assets and make money from games makes GameFi very attractive, especially in developing countries.
#
# The current GameFi landscape consists mostly of "weakly" on-chain games with a focus on *play-to-earn*: in-game rewards can be transacted as NFTs on crypto exchanges and marketplaces, allowing players to cash them out into other cryptocurrencies and ultimately fiat. The actual gameplay however, is (still) mostly a second priority making current web3 games being dis-engaging and tedious to play with.
#
# Although static games like *Axies Infinity* still hold the majority of the GameFi market we are starting to see the rise of higher quality metaverse games such as *Decentraland* and *The Sandbox*.
#
# A typical **triple A** game takes years to be built. For example the famous *Grand Theft Auto* by Rockstar took 3 years to develop and with smart contracts being relatively new, it is expected that a true triple A game is still at least a couple of years away.
#
# *Mimic Labs* tried to predict the future devolopment by looking into the speed of recent VR development and came to the conclusion that first triple A games probably won't be released before 2028:
#
# <img src='https://www.dropbox.com/s/u7sjgzi70p4y7iq/GameFi_future.png?raw=1' width=500px>
#
# In the meantime it can be expected that more and more triple A game studios enter the blockchain world, bringing experienced game developer into the GameFi ecosystem and potentially transferring sucessfull traditionall games into the system. The *metaverse hype* might foster this trend.
# One example of such a studio is *WorldSpark*. With a team formed from multiple triple A game studios, the company raised $3 million in seed funding and is developing an on-chain action MOBA (Multiplayer online battle arena) game entitled [Edenbrawl](https://www.edenbrawl.com) which is worth to have a sneek preview into.
#
# In general we might see more advanced on-chain games in which not only *play-to-earn* but more and more *play-for-fun* content dominates.
# On the other side crypto gaming as a source of income might raise more and more attention in developing countries where players sometimes could earn more by playing than through their regular job. For example: the majority of Axie Infinity’s daily active users (DAUs) are in the Philippines where players play as an employee in behalf of their principals account. <a name="cite_ref-PAN"></a>[<sup>[PAN]</sup>](#cite_note-PAN)

# %% [markdown]
# ### Your Deliverables, your time to apply the theory in practice.
#
# Congratulations on getting to the end of this Notebook and no worries at all if you struggled with some of the theory and did not fully understand what was taught here as your actual learning starts from here.
#
# The ideal time of reading this, is right before the Review Session, so you have a bit of time to reflect about the learning material, identify the most confusing and hard elements of a reading, and bring them to the discussion during the Review Session. The Review session is there for you to close the gap in your current understanding of the material.
#
# For your deliverables you will have to work on the Workbook found [here](https://colab.research.google.com/github/unpackAI/BL101/blob/main/course_notebooks/Week_4_GameFi%26SocialFi/04_GameFi_SocialFi_Workbook.ipynb)!

# %% [markdown]
# ---
# # References 📚
#
#
#
# **Game economy**
# - [Axie Downfall](https://www.theverge.com/2022/4/8/23015468/axie-infinity-blockchain-nft-play-to-earn-game-economics-hack#:~:text=Axie%20Infinity's%20economy%20is%20built,resources%20in%20constantly%20increasing%20quantities.)
# - [Gaming Economy](https://departmentofplay.net/tokenomics-how-to-design-economies-for-crypto-games/#Inflation)
#
# **Example Cases**
# - Axie Infinity, (2012). [Official Axie Infinity Whitepaper](https://whitepaper.axieinfinity.com/) 📄
# - [Genopets Whitepaper v3.2](https://docsend.com/view/b9bqd2j78nekzdgr) 📄
#
# **On-chain gaming**
# - @3pa15, (2022). [Thoughts on on-chain gaming](https://dialectic.ch/editorial/thoughts-on-chain-gaming) 📄
# - <sup>[CHE]</sup> Sylve Chevet, (2021). [Four challenges in blockchain gaming](https://mirror.xyz/sylve.eth/6QJ6taBcobFAWMbijs4WrQrFZ_FGq5wXmJ_NIXW-GmQ) 📄 <a name="cite_note-CHE"></a>[🔙](#cite_ref-CHE)
# - Ronan Sandford, (2020). [Building a Game Fully On Chain](https://www.youtube.com/watch?v=3_WLjLsYUbM), *Youtube* 📺
#
#
# **Industry**
# - Jonathan Yantis et al. (2018) [WAX Whitepaper](https://whitepaper.io/document/81/wax-1-whitepaper), *version 1.9* 📄
# - Leeway Hertz, (2012). [Metaverse-Use cases and benefits](https://medium.com/javarevisited/metaverse-use-cases-and-benefits-206e6fab3d67) *Medium Article*  📄💲
# - YellowHeart [YellowHeart Protocol Whitepaper](https://static.yh.io/about/assets/pdf/yellowheart-protocol-whitepaper.pdf), *version 1.1* 📄
# - Finance Magnates, (2022). [Sandbox (SAND): The complete guide](https://www.financemagnates.com/cryptocurrency/education-centre/sandbox-sand-the-complete-guide/) *What is Sandbox (SAND) and why you need to know* 📄
# - Luozhu Zhang, (2022). [Zero-Knowledge Rollups](https://ethereum.org/en/developers/docs/scaling/zk-rollups/) *Ethereum Docs* 📄
# - Esteban Ordano et al., (n.d.). [Decentraland Whitepaper](https://tokeninsight.com/api/upload/whitePaper/Decentraland_en.pdf) 📄
# - Stuart James, (2022). [Universal basic income (UBI)](https://blog.kleros.io/proof-of-humanity-an-explainer/) *An explainer on how to register for Proof of Humanity and use the platform.* 📄
# - Cometh, (2021). [Cometh White Paper](https://www.cometh.io/white-paper-cometh.pdf), *version 2.0.0* 📄
#
# **Future Development**
# - Mimic Labs (2022). [The Future of GameFi](https://mimic-labs.com/2022/06/the-future-of-gamefi/), *capital.com* 📄
# - <sup>[PAN]</sup> Alexandra Pankratyeva (2021). [Crypto games: play-to-earn phenomenon](https://capital.com/crypto-games-play-to-earn-phenomenon) 📄  <a name="cite_note-PAN"></a>[🔙](#cite_ref-PAN)
#
# ---
#
# **Games/Projects**
# - [Alien Worlds](https://alienworlds.io/) 👈🏻 *Players can find NFTs which they can use to connect and play with others.*
# - [Axies Infinity](https://axieinfinity.com) 👈🏻 *NFT-based game with in-game economy which uses Ethereum*
# - [Cometh](https://www.cometh.io/) 👈🏻 *free-to-play tactical card game in space environment - running end-to-end on smart contracts*
# - [Decentraland](https://decentraland.org/) 👈🏻 *a virtual reality platform where users can create, experience, and monetize content and applications and buy land*
# - [Dope Wars](https://dopewars.gg/) 👈🏻 *fully decentralized, community driven, gaming metaverse project inspired by hip-hop culture*
# - [Edenbrawl](https://www.edenbrawl.com) 👈🏻 *on-chain action multiplayer online battle arena (in development)*
# - [Genopets](https://www.genopets.me) 👈🏻  *worlds forst move-to-earn NFT game*
# - [Influence](https://www.influenceth.io/) 👈🏻 *space strategy MMO in which players colonize asteroids, build infrastructure, discover technologies and engage in combat*
# - [Sorare](https://sorare.com/) 👈🏻 *on-chain community of football fans*
# - [Stepn](https://stepn.com/) 👈🏻 *lifestyle app that rewards users for movement: user equipped with NFTs can earn by walking, jogging and running outdoors*
# - [The Sandbox](https://www.sandbox.game/en/) 👈🏻 *crypto game with huge NFT marketplace on the metaverse*
# - [TIME Pieces](https://time.com/collection/timepieces-nft/) 👈🏻  *NFT collection community by Time Magazin*
# - [YellowHeart](https://yh.io/about/)  👈🏻 *NFT ticketing and music company, connecting artists with fans*
