# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/unpackAI/BL101/blob/main/course_notebooks/Week_5_Decentralised_autonomous_organizations%28DAOs%29/05_Decentralised_autonomous_organizations%28DAOs%29_Workbook.ipynb)

# %% [markdown]
# # 💻 Week 5 Workbook of unpackAI "BC101 Bootcamp"
# You have successfully finished the forth week! You are almost at the end of this Bootcamp. Having covered the main areas of application, we will now be diving into the governance of blockchain-based applications, namely DAOs.
#
# ## 📕 Learning Objectives
#
# * What are DAOs and what makes them the perfect governing entity in a web3 world.
# * Build your own DAO using the Aragon UI and list it on DeepDao.
# * Work on your final project and build your own Blockchain Startup.

# %% [markdown]
# ---
# ## Assignment: 👷‍♀️ Create a DAO and pitch your own Blockchain startup🚀

# %% [markdown]
# ---

# %% [markdown]
# ### 1️⃣ Connect to the Rinkeby Testnet and Create your DAO
#
# Navigate to [**Aragon.org**](https://aragon.org/) and enter the **Create a DAO** button. The Aragon UI will lead you through the following process to make all the fundamental decisions necessary when creating your own DAO.
#
# 1️⃣ Select template --> 2️⃣ Claim a name 3️⃣ --> Configure template 4️⃣ --> Review information 5️⃣ --> Launch organization
#
# As the DAO comes in form of several smart contracts, we will be interacting with the Rinkeby to showcase the power of Aragon, while avoiding the gas fees.
#
# > Aragon is an open-source software used to maintain and create decentralized autonomous organizations (DAOs) on the Ethereum blockchain.
#
# <center><img src="https://www.dropbox.com/s/sldl89ikq8o6c1z/DAO_Creation.png?raw=1" alt="dao_creation" width="800"/></center>
#
# One of the most fundamental decisions that you will have to make is how your DAO will be governed. Like we covered within the coursebook, the voting mechanism to determine voting power heavily influences the kind of DAO you would like to create. Aside from a few other options, Aragon gives you 3 main options.
#
# <center><img src="https://www.dropbox.com/s/wwvgx3ajwg5wfir/type_of_dao.png?raw=1" alt="dao_creation" width="600"/></center>
#
# - **Company**: This DAO utilizes the transferrable token voting power mechanism. Essentially, the more governance tokens you have, the more influential you will become on the DAO's decisions. In this case, since tokens can be bought, influence can be bought as well.
# - **Membership**: This DAO utilizes the one-member-one-vote voting mechanism. This is in line with the proof-of-personhood participation model that we discussed. However, since one member could create several wallets, this is not bullet proof.
# - **Reputation**: This DAO also utilizes the non-tranferrable token voting power voting mechanism. While the amount of tokens you own, also represent the amount of influence you have, you are not able to buy or sell the token. The token is send or erased from your wallet based on your positive or negative impact on the DAO. This mechanism hols similar elements to the skin-in-the-game model that we discussed.
#
# Go through the rest of the process to launch your DAO. If you need any help you may also inquire the [Aragon Documentation](https://documentation.aragon.org/products/aragon-client/how-to-create-a-dao-using-aragon-client).

# %% [markdown]
# ### 2️⃣ Head over to DeepDao.io and make sure you've been listed for their analytics.
#
# Connect your wallet on [**DeepDao.io**](DeepDao.io) and list your DAO.
#
# > Deep DAO is a data analytics site for decentralized autonomous organizations. DeepDAO presents extensive analytics and information gathering. The main dashboard product enumerates and ranks DAOs using several key metrics such as membership and assets under management (AUM).
#
# You will require your Token Address, Governance Address, and Treasury Address. You will find all these within your Aragon Organization Settings page. The Treasury page responds to the Finance Address. Finalize the process by listing your DAO and viewing your DeepDao page.
#
# <center><img src="https://www.dropbox.com/s/clodtnzkyfvm94p/deep_dao.png?raw=1" alt="dao_creation" width="800"/></center>
#
# If you want to seriously consider further building your DAO, you might want to take further steps, such as forming a legal wrapper. Take note that this goes beyond the course, however, you can feel free to explore [here](https://documentation.aragon.org/products/aragon-client/things-to-do-after-youve-started-a-dao).

# %% [markdown]
# ### 3️⃣ Prepare your final Bootcamp project.
#
# You have gotten very far. Over the last 5 weeks, you have explored the main areas of applications of the Blockchain. We hope you were able to see the potentials, as well as the shortcomings of this new paradigm technology. To know and understand is truly crucial to build your own project. Remember, we are at the forefront of Blockchain, and no one is absolutely certain where this new industry.
#
# We hope you will join the revolution, and be part of the growing talent base to make this future a reality. For this, the final task of this course will be to create your own Blockchain startup and pitch it to the community.
#
# Your startup should be based on a **Blockchain Business Model**. A business model describes a plan or strategy of a company to sell a product or service and earn profit from there. A blockchain business model has all the three main characteristics of blockchain technology: it is decentralized, based on peer-to-peer transactions, within a trusted and reliable network.

# %% [markdown]
# To make it easier for your we give you an framework to develop your Blockchain Business Model:
#
# <center><img src="https://www.dropbox.com/s/rtc9ajlz0ztx8b1/VBDE-framework.png?raw=1" alt="VBDE Framework"/></center>
#
#  The framework consists of 4 parts: values, blockchain model, distribution and economic model. *You can use this framework, adapt it / enhance it / alter it to meet your project goal.* 🏗👷🏻‍♂️🚧
#
# #### 3️⃣.1️⃣ Summarize your Project 📋📎
# 🚠 You know what an **Elevator Pitch** is?
# - it's a short description of an business idea that explains the concept in a way such that any listener can understand it in a short period of time. *You explain what your "thing" is for, what it does, why it is needed, and how it will get done.*
#
# Do this in this introductory chapter. Convince us in a few sentences 📝 or insert a short video of you 🎥💁🏻‍♀️ about your project. Why should we invest in your startup?
#
# *Of course you should have already developed your bootcamp project idea so far.*
#
# #### 3️⃣.2️⃣ Value Model 🏆
# >In the value model we want to answer a few core questions:
# - **Core Philosophy:** *What's the long term hard problem your business is solven?*
# - **Core Values:** *What key values drive your business idea?*
# - **Value Propoition:** *What set of values each stakeholder gets from your business?*
#
# #### 3️⃣.3️⃣ Blockchain Model  ⛓⚙️
# >In the Blockchain Model we want to understand how the protocol (which blockchain, what layer, etc.) connects the value model to everything else.
# - **Protocols Rules:** *What rules govern the Blockchain?*
# - **Network Shape:** *What network shape do the protocol rules determine?*
# - **Applications Rules:** *Which applications can be built on top of the protocol?*
#
# #### 3️⃣.4️⃣ Distribution Model 🚚
# >Here we want to understand how the various pieces come together to make the underlying Blockchain ecosystem sustainable and keep growing it.
# - **Developer Community:** *Is the developer community engaged in developing apps on top of the Blockchain? What does it take to keep it engaged?*
# - **Investor Relations:** *Are the underlying crypto token valuable for potential investors?*
# - **Mining Incentives:** *What incentives exist for miners to keep contributing to the development and growth of the Blockchain network?*
# - **Deal Making:** *What agreements are in place integrating the protocols through institutional & non-institutional channels?*
#
#
# #### 3️⃣.5️⃣ Economic Model 📊📈
# >How does the underlying crypto asset gain value & how do the apps monetize?
#
# - How is the Blockchain crypto asset gaining value and how the key players part of the ecosystem are monetizing the applications built on top of it? Or very simple: *how do App users make money?*

# %% [markdown]
# ### I *really really really* don't know how to start 🙇‍♂️🤷🏽‍♀️🤦🏻‍♂️
# Why don't you start with a simple *Business Model Canvas* like this?
#
# <center><img src="https://www.dropbox.com/s/a1kn9wqjmg5ddbr/Blockchain-Business-Model-Canvas.jpeg?raw=1" alt="Blockchain Business Model Canvas"/></center>
#
# ... and have a look into some general blockchain business models:
# <center><img src="https://www.dropbox.com/s/d24l2dszt90mkj9/Top-7-Blockchain-Business-Models.jpg?raw=1" alt="Top 7 Blockchain Business Models"/></center>

# %% [markdown]
# ---
# # 📚 Reference
# - Gennaro Cuofano, (2022). [VBDE Framework: Dissecting Blockchain Business Models](https://fourweekmba.com/vbde-framework/) 📄
# - Daniel Pereira, (2022). [Blockchain Business Models](https://businessmodelanalyst.com/blockchain-business-models/) 📄
# ---
# # Appendix: Where can you go from here? 🚶🏾‍♂️
# >🎖 *This part is fully optional!*
#
# ## 🎧 Listen to the experience 👴🏽 of a founding member of an investment DAO 🏦🕴🏻
# Coinbase (2021). [The realities of working for a DAO with Kinjal Shah](https://youtu.be/dc_vie35T3c?t=203), *Youtube* 📺
#
# ## ... and like always we recommend 📺 +👨‍💻 from **Patrick**
# >this is how we all learnt 🏋️‍♂️ web3. Patrick also covers DAOs in a seperate chapter. His code is written in `javascript` with `hardhat` libary:
# - Patrick Collins, (2022). [Learn Blockchain, Solidity, and Full Stack Web3 Development with JavaScript, Chapter 17 Build a DAO](https://youtu.be/gyMwXuJrbJQ?t=107124) 📺 🏋️‍♂️
#
# *Unfortunately, his `Python` version does not have a lesson about DAOs* 😢
